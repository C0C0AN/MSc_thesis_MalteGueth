# %%
# Quick example of how to load data previously preprocessed in eeglab into mne python
# and generate a 3d animated topo map of the evoked data (https://gist.github.com/kingjr/061f28265555ac97329d2c80132d1b57)

import mne
import mne.io.eeglab

n_channels = 64
s_freq = 256
n_samples = 1152
ch_names = ('Fp1','AF7','AF3','F1','F3','F5','F7','FT7','FC5','FC3','FC1','C1','C3','C5','T7','TP7','CP5','CP3','CP1',
            'P1','P3','P5','P7','P9','PO7','PO3','O1','Iz','Oz','POz','Pz','CPz','Fpz','Fp2','AF8','AF4','AFz','Fz',
            'F2','F4','F6','F8','FT8','FC6','FC4','FC2','FCz','Cz','C2','C4','C6','T8','TP8','CP6','CP4','CP2','P2','P4',
            'P6','P8','P10','PO8','PO4','O2')
chanlocs = mne.channels.read_montage(kind='biosemi64')
info = mne.create_info(ch_names, s_freq, ch_types='eeg', montage=chanlocs)

# %%
data_path_3_1 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub1_B_25.set'
data_path_3_2 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub2_B_25.set'
data_path_3_3 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub3_B_25.set'
data_path_3_4 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub4_B_25.set'
data_path_3_5 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub5_B_25.set'
data_path_3_6 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub6_B_25.set'
data_path_3_7 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub7_B_25.set'
data_path_3_8 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub8_B_25.set'
data_path_3_9 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub9_B_25.set'
data_path_3_10 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub10_B_25.set'
data_path_3_11 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub11_B_25.set'
data_path_3_12 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub12_B_25.set'
data_path_3_13 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub13_B_25.set'
data_path_3_14 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub14_B_25.set'
data_path_3_15 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub15_B_25.set'
data_path_3_16 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub16_B_25.set'
data_path_3_17 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub17_B_25.set'
data_path_3_18 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub18_B_25.set'
data_path_3_19 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub19_B_25.set'
data_path_3_20 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub20_B_25.set'
data_path_3_21 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub21_B_25.set'
data_path_3_22 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub22_B_25.set'
data_path_3_23 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub23_B_25.set'
data_path_3_24 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub24_B_25.set'
data_path_3_25 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub25_B_25.set'
data_path_3_26 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub26_B_25.set'
data_path_3_27 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub27_B_25.set'
data_path_3_28 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub28_B_25.set'
data_path_3_29 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub29_B_25.set'
data_path_3_30 = '/Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub30_B_25.set'

# %%
epochsB_3_1 = mne.io.read_epochs_eeglab(data_path_3_1, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_2 = mne.io.read_epochs_eeglab(data_path_3_2, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_3 = mne.io.read_epochs_eeglab(data_path_3_3, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_4 = mne.io.read_epochs_eeglab(data_path_3_4, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_5 = mne.io.read_epochs_eeglab(data_path_3_5, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_6 = mne.io.read_epochs_eeglab(data_path_3_6, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_7 = mne.io.read_epochs_eeglab(data_path_3_7, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_8 = mne.io.read_epochs_eeglab(data_path_3_8, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_9 = mne.io.read_epochs_eeglab(data_path_3_9, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_10 = mne.io.read_epochs_eeglab(data_path_3_10, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_11 = mne.io.read_epochs_eeglab(data_path_3_11, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_12 = mne.io.read_epochs_eeglab(data_path_3_12, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_13 = mne.io.read_epochs_eeglab(data_path_3_13, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_14 = mne.io.read_epochs_eeglab(data_path_3_14, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_15 = mne.io.read_epochs_eeglab(data_path_3_15, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_16 = mne.io.read_epochs_eeglab(data_path_3_16, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_17 = mne.io.read_epochs_eeglab(data_path_3_17, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_18 = mne.io.read_epochs_eeglab(data_path_3_18, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_19 = mne.io.read_epochs_eeglab(data_path_3_19, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_20 = mne.io.read_epochs_eeglab(data_path_3_20, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_21 = mne.io.read_epochs_eeglab(data_path_3_21, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_22 = mne.io.read_epochs_eeglab(data_path_3_22, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_23 = mne.io.read_epochs_eeglab(data_path_3_23, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_24 = mne.io.read_epochs_eeglab(data_path_3_24, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_25 = mne.io.read_epochs_eeglab(data_path_3_25, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_26 = mne.io.read_epochs_eeglab(data_path_3_26, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_27 = mne.io.read_epochs_eeglab(data_path_3_27, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_28 = mne.io.read_epochs_eeglab(data_path_3_28, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_29 = mne.io.read_epochs_eeglab(data_path_3_29, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
epochsB_3_30 = mne.io.read_epochs_eeglab(data_path_3_30, events=None, event_id=None, montage=chanlocs, eog=(), verbose=None, 
                                   uint16_codec=None)
# Out:
# Extracting parameters from /Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub1_B_25.set...
# 26 matching events found
# 0 projection items activated
# Ready.
# Extracting parameters from /Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub2_B_25.set...
# 25 matching events found
# 0 projection items activated
# Ready.
# Extracting parameters from /Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub3_B_25.set...
# 26 matching events found
# 0 projection items activated
# Ready.
# Extracting parameters from /Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub4_B_25.set...
# 26 matching events found
# 0 projection items activated
# Ready.
# Extracting parameters from /Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub5_B_25.set...
# 26 matching events found
# 0 projection items activated
# Ready.
# Extracting parameters from /Volumes/INTENSO/DPX_Baseline//50Hz/First_Block/Sub6_B_25.set...
# 24 matching events found
# 0 projection items activated
# Ready.
# ...

# %%
conv_epochsB_3_1 = mne.EpochsArray(epochsB_3_1, info=info, tmin=-0.25)
conv_epochsB_3_2 = mne.EpochsArray(epochsB_3_2, info=info, tmin=-0.25)
conv_epochsB_3_3 = mne.EpochsArray(epochsB_3_3, info=info, tmin=-0.25)
conv_epochsB_3_4 = mne.EpochsArray(epochsB_3_4, info=info, tmin=-0.25)
conv_epochsB_3_5 = mne.EpochsArray(epochsB_3_5, info=info, tmin=-0.25)
conv_epochsB_3_6 = mne.EpochsArray(epochsB_3_6, info=info, tmin=-0.25)
conv_epochsB_3_7 = mne.EpochsArray(epochsB_3_7, info=info, tmin=-0.25)
conv_epochsB_3_8 = mne.EpochsArray(epochsB_3_8, info=info, tmin=-0.25)
conv_epochsB_3_9 = mne.EpochsArray(epochsB_3_9, info=info, tmin=-0.25)
conv_epochsB_3_10 = mne.EpochsArray(epochsB_3_10, info=info, tmin=-0.25)
conv_epochsB_3_11 = mne.EpochsArray(epochsB_3_11, info=info, tmin=-0.25)
conv_epochsB_3_12 = mne.EpochsArray(epochsB_3_12, info=info, tmin=-0.25)
conv_epochsB_3_13 = mne.EpochsArray(epochsB_3_13, info=info, tmin=-0.25)
conv_epochsB_3_14 = mne.EpochsArray(epochsB_3_14, info=info, tmin=-0.25)
conv_epochsB_3_15 = mne.EpochsArray(epochsB_3_15, info=info, tmin=-0.25)
conv_epochsB_3_16 = mne.EpochsArray(epochsB_3_16, info=info, tmin=-0.25)
conv_epochsB_3_17 = mne.EpochsArray(epochsB_3_17, info=info, tmin=-0.25)
conv_epochsB_3_18 = mne.EpochsArray(epochsB_3_18, info=info, tmin=-0.25)
conv_epochsB_3_19 = mne.EpochsArray(epochsB_3_19, info=info, tmin=-0.25)
conv_epochsB_3_20 = mne.EpochsArray(epochsB_3_20, info=info, tmin=-0.25)
conv_epochsB_3_21 = mne.EpochsArray(epochsB_3_21, info=info, tmin=-0.25)
conv_epochsB_3_22 = mne.EpochsArray(epochsB_3_22, info=info, tmin=-0.25)
conv_epochsB_3_23 = mne.EpochsArray(epochsB_3_23, info=info, tmin=-0.25)
conv_epochsB_3_24 = mne.EpochsArray(epochsB_3_24, info=info, tmin=-0.25)
conv_epochsB_3_25 = mne.EpochsArray(epochsB_3_25, info=info, tmin=-0.25)
conv_epochsB_3_26 = mne.EpochsArray(epochsB_3_26, info=info, tmin=-0.25)
conv_epochsB_3_27 = mne.EpochsArray(epochsB_3_27, info=info, tmin=-0.25)
conv_epochsB_3_28 = mne.EpochsArray(epochsB_3_28, info=info, tmin=-0.25)
conv_epochsB_3_29 = mne.EpochsArray(epochsB_3_29, info=info, tmin=-0.25)
conv_epochsB_3_30 = mne.EpochsArray(epochsB_3_30, info=info, tmin=-0.25)
# Out:
# 26 matching events found
# 0 projection items activated
# 0 bad epochs dropped
# 25 matching events found
# 0 projection items activated
# 0 bad epochs dropped
# 26 matching events found
# 0 projection items activated
# 0 bad epochs dropped
# 26 matching events found
# 0 projection items activated
# 0 bad epochs dropped
# 26 matching events found
# 0 projection items activated
# 0 bad epochs dropped
# 24 matching events found
# 0 projection items activated
# 0 bad epochs dropped
# 29 matching events found
# 0 projection items activated
# 0 bad epochs dropped
# 26 matching events found
# 0 projection items activated
# 0 bad epochs dropped
# 24 matching events found
# 0 projection items activated
# 0 bad epochs dropped
# 25 matching events found
# 0 projection items activated
# 0 bad epochs dropped
# 20 matching events found
# 0 projection items activated
# 0 bad epochs dropped
# 26 matching events found
# 0 projection items activated
# 0 bad epochs dropped
# 25 matching events found
# ...

# %%
evokedB_3_1 = conv_epochsB_3_1.average()
evokedB_3_2 = conv_epochsB_3_2.average()
evokedB_3_3 = conv_epochsB_3_3.average()
evokedB_3_4 = conv_epochsB_3_4.average()
evokedB_3_5 = conv_epochsB_3_5.average()
evokedB_3_6 = conv_epochsB_3_6.average()
evokedB_3_7 = conv_epochsB_3_7.average()
evokedB_3_8 = conv_epochsB_3_8.average()
evokedB_3_9 = conv_epochsB_3_9.average()
evokedB_3_10 = conv_epochsB_3_10.average()
evokedB_3_11 = conv_epochsB_3_11.average()
evokedB_3_12 = conv_epochsB_3_12.average()
evokedB_3_13 = conv_epochsB_3_13.average()
evokedB_3_14 = conv_epochsB_3_14.average()
evokedB_3_15 = conv_epochsB_3_15.average()
evokedB_3_16 = conv_epochsB_3_16.average()
evokedB_3_17 = conv_epochsB_3_17.average()
evokedB_3_18 = conv_epochsB_3_18.average()
evokedB_3_19 = conv_epochsB_3_19.average()
evokedB_3_20 = conv_epochsB_3_20.average()
evokedB_3_21 = conv_epochsB_3_21.average()
evokedB_3_22 = conv_epochsB_3_22.average()
evokedB_3_23 = conv_epochsB_3_23.average()
evokedB_3_24 = conv_epochsB_3_24.average()
evokedB_3_25 = conv_epochsB_3_25.average()
evokedB_3_26 = conv_epochsB_3_26.average()
evokedB_3_27 = conv_epochsB_3_27.average()
evokedB_3_28 = conv_epochsB_3_28.average()
evokedB_3_29 = conv_epochsB_3_29.average()
evokedB_3_30 = conv_epochsB_3_30.average()

# %%
list3 = [evokedB_3_1, evokedB_3_2, evokedB_3_3, evokedB_3_4, evokedB_3_5, evokedB_3_6, evokedB_3_7, evokedB_3_8, evokedB_3_9, evokedB_3_10,
         evokedB_3_11, evokedB_3_12, evokedB_3_13, evokedB_3_14, evokedB_3_15, evokedB_3_16, evokedB_3_17, evokedB_3_18, evokedB_3_19,
         evokedB_3_20, evokedB_3_21, evokedB_3_22, evokedB_3_23, evokedB_3_24, evokedB_3_25, evokedB_3_26, evokedB_3_27, evokedB_3_28,
         evokedB_3_29, evokedB_3_30]

# %%
evokedB_bl1 = mne.grand_average(list3)
# Out:
# Identiying common channels ...
# all channels are corresponding, nothing to do.

# %%
import numpy as np
import matplotlib.pyplot as plt
import mne
import os.path as op
from scipy.spatial import Delaunay
import ipyvolume as p3

evoked = evokedB_bl1.pick_types(meg=False, eeg=True)

# %%
# transform evoked into colors
cmap = plt.get_cmap('RdBu_r')
data = np.array(evoked.data)
n_chans, n_times = data.shape
vmax = data.max()
data[data<=-vmax] = -vmax
data[data>=vmax] = vmax
data -= -vmax
data /= 2*vmax
colors = np.reshape(cmap(data.ravel())[:, :3], [n_chans, n_times, 3])
colors = colors.transpose(1, 0, 2)

# set up 3D mesh
pos3D = np.array([ch['loc'][:3] for ch in evoked.info['chs']])
tri3D = Delaunay(pos3D).convex_hull

# %%
# plot
fig = p3.figure()
s = p3.plot_trisurf(pos3D[:, 0], pos3D[:, 1], [pos3D[:, 2] for _ in range(n_times)],
                    triangles=tri3D, color=colors)
p3.xyzlim(pos3D.min(), pos3D.max())
p3.animation_control(s, interval=10)
p3.show()
# Out:
# A Jupyter Widget

# %%
# set up 2D topography
pos = mne.find_layout(evoked.info).pos[:, :3]
pos -= pos.mean(0, keepdims=True)
pos[:, 2] = (1-(pos[:, 0] ** 2 + pos[:, 1] ** 2))/1e3
tri2D = Delaunay(pos).convex_hull

# %%
# plot
fig = p3.figure()
s = p3.plot_trisurf(pos[:, 0], pos[:, 1], [pos[:, 2] for _ in range(n_times)],
                    triangles=tri2D, color=colors)
p3.xyzlim(pos.min(), pos.max())
p3.animation_control(s, interval=10, add=True)
p3.show()
# Out:
# A Jupyter Widget
